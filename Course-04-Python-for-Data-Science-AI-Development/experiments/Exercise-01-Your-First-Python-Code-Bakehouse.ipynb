# %%
## Bakehouse Application

# %%
# Exercise 01 - Your First Python Code
# Application: Immanuel's Bakehouse

# %%
flour_cost = 60
chocolate_cost = 250
batch_quantity = 6
selling_price = 600
print(flour_cost)
print(chocolate_cost)
print(batch_quantity)
print(selling_price)
# Out:
# 60
# 250
# 6
# 600

# %%
product_name = "Chocolate Brownie"
flour_cost = 60.50
chocolate_cost = 250.00
batch_quantity = 6
selling_price = 600.00
product_available = True
print(product_name)
print(flour_cost)
print(chocolate_cost)
print(batch_quantity)
print(selling_price)
print(product_available)
# Out:
# Chocolate Brownie
# 60.5
# 250.0
# 6
# 600.0
# True

# %%
# Data
product_name = "Chocolate Truffle Cake"
batch_id = "BATCH-2026-0903-01"
order_reference = "ORD-IB-1045"

print(product_name)
print(batch_id)
print(order_reference)
# Out:
# Chocolate Truffle Cake
# BATCH-2026-0903-01
# ORD-IB-1045

# %%
# String operations
print(product_name.upper())
print(product_name[:9])
print(batch_id.split("-"))
# Out:
# CHOCOLATE TRUFFLE CAKE
# Chocolate
# ['BATCH', '2026', '0903', '01']

# %%
#searching/replacement examples
print(product_name.find("Truffle"))
updated_product =product_name.replace("Chocolate", "Dark Chocolate")
print(updated_product)
# Out:
# 10
# Dark Chocolate Truffle Cake
